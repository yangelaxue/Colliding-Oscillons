# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
gamma = lambda v : 1/np.sqrt(1-v**2)

# %%
v = np.linspace(0,1,100)

# %%
plt.plot(v, gamma(v))
# Out:
# /tmp/ipykernel_6766/2843645327.py:1: RuntimeWarning: divide by zero encountered in divide
#   gamma = lambda v : 1/np.sqrt(1-v**2)

# %%
gamma(0.2)
# Out:
# 1.0206207261596576
